# %%
import glob
import pandas as pd

# %%
glob.glob("./data/*.xlsx")
# Out:
# ['./data/cpn-dwh-data.xlsx']

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### dim_contract
# -

# %%
df_dim_contract = pd.read_excel("./data/cpn-dwh-data.xlsx", sheet_name="dim_contract")
df_dim_contract.head()
# Out:
#       ContractId  CompanyCode ContractNumber         ObjectNumber  \
# 0  IS00100000318         1007  BNA1252000001  IS1007BNA1252000001
# 1  IS00100000319         1007  BNA1252000002  IS1007BNA1252000002
# 2  IS00100000320         1007  BNA1252000003  IS1007BNA1252000003
# 3  IS00100000321         1007  BNA1252000004  IS1007BNA1252000004
# 4  IS00100000322         1007  BNA1252000005  IS1007BNA1252000005
#
#   ContractType ContractStartDate TermEndDate           ContractName  \
# 0         Z520        2012-05-06  2013-05-05           TAKE A TOAST
# 1         Z520        2012-05-10  2013-05-09           BAPPLE DONUT
# 2         Z520        2012-05-05  2013-05-04                 GELATE
# 3         Z520        2012-10-25  2013-10-24  GLORIA JEAN'S COFFEES
# 4         Z520        2012-06-20  2013-06-19                  AKIKO
#
#    MainContractCompanyCode MainContractNumber  OldContract IndustryId  \
# 0                      NaN                NaN     30111161   ZTFB0005
# ...

# %% [markdown]
# ### rel_ro_contract_id
# - abc

# %%
df_rel_ro_contract_id = pd.read_excel("./data/cpn-dwh-data.xlsx", sheet_name="rel_ro_contract_id")
df_rel_ro_contract_id.head()
# Out:
#             ROId     ContractId  ValidFrom    ValidTo          ROObjectNumber  \
# 0  IM00100000000  IS00100002823 2013-04-01 2013-10-24  IM1003TBE     08000001
# 1  IM00100000000  IS00100031312 2013-10-25 2014-07-31  IM1003TBE     08000001
# 2  IM00100000000  IS00100086223 2014-08-01 2015-07-31  IM1003TBE     08000001
# 3  IM00100000000  IS00100146029 2015-08-01 2015-10-24  IM1003TBE     08000001
# 4  IM00100000000  IS00100179839 2016-02-19 2016-05-31  IM1003TBE     08000001
#
#   ContractObjectNumber  ROCompanyCode  ContractCompanyCode BECode  UnitNumber  \
# 0  IS1007TBNA135100001           1003                 1007    TBE     8000001
# 1  IS1007TBNA135100006           1003                 1007    TBE     8000001
# 2  IS1007TBNA145100001           1003                 1007    TBE     8000001
# 3  IS1007TBNA155100001           1003                 1007    TBE     8000001
# 4  IS1007TBNA165400006           1003                 1007    TBE     8000001
#
# ...

# %% [markdown]
# ### dim_ro
# - abc

# %%
df_dim_ro = pd.read_excel("./data/cpn-dwh-data.xlsx", sheet_name="dim_ro")
df_dim_ro.head()
# Out:
#             ROId  CompanyCode BECode BranchCode  UnitNumber  \
# 0  IM00100000000         1003    TBE        BNA     8000001
# 1  IM00100000001         1003    TBE        BNA     8000002
# 2  IM00100000002         1003    TBE        BNA     8000003
# 3  IM00100000003         1003    TBE        BNA     8000004
# 4  IM00100000004         1003    TBE        BNA     8000005
#
#              ObjectNumber  ValidFrom              ValidTo  UsageTypeId  \
# 0  IM1003TBE     08000001        NaN  2017-12-31 00:00:00         1200
# 1  IM1003TBE     08000002        NaN  2017-12-31 00:00:00         1200
# 2  IM1003TBE     08000003        NaN  2017-12-31 00:00:00         1200
# 3  IM1003TBE     08000004        NaN  2017-12-31 00:00:00         1200
# 4  IM1003TBE     08000005        NaN  2017-12-31 00:00:00         1200
#
#             ROName BuildingNumber         UnitName PartOfBuilding  \
# 0  (ห้ามใช้)FFS717            BNA  (ห้ามใช้)FFS717             1N
# ...

# %% [markdown]
# ### ref_floor
# - abc

# %%
df_ref_floor = pd.read_excel("./data/cpn-dwh-data.xlsx", sheet_name="ref_floor")
df_ref_floor.head()
# Out:
#    Floor LanguageKey ShortDescription                 LongDescription  \
# 0      0          DE                0  nicht benutzen: Initialeintrag
# 1      0          EN                0      Do not use: Initialization
# 2      0          TH                0    ห้ามใช้: การกำหนดค่าเริ่มต้น
# 3     81          EN                M                               M
# 4     82          EN               1M                              1M
#
#    LOAD_ID                                PKG_ID  ASAT_DATE  \
# 0  2663552  F922AB46-14CA-4CB6-8BA7-39ABB8286939 2024-10-31
# 1  2663552  F922AB46-14CA-4CB6-8BA7-39ABB8286939 2024-10-31
# 2  2663552  F922AB46-14CA-4CB6-8BA7-39ABB8286939 2024-10-31
# 3  2663552  F922AB46-14CA-4CB6-8BA7-39ABB8286939 2024-10-31
# 4  2663552  F922AB46-14CA-4CB6-8BA7-39ABB8286939 2024-10-31
#
#                    INS_DT               INS_BY  UPD_DT  UPD_BY
# 0 2024-11-01 17:36:25.217  HOLP.COM\CPNDWBATCH     NaN     NaN
# ...

# %% [markdown]
# ### rel_bp_contract_id
# - abc

# %%
df_rel_bp_contract_id = pd.read_excel("./data/cpn-dwh-data.xlsx", sheet_name="rel_bp_contract_id")
df_rel_bp_contract_id.head()
# Out:
#                  BPObjectRelationshipId     ContractId  BPNumber  BPRole  \
# 0  514B3CA2-1322-1B80-E100-80000A093738  I600100000000   2001483  ZBP310
# 1  514B3CA5-1322-1B80-E100-80000A093738  I600100000000  10000453  ZBP400
# 2  514B3CA8-1322-1B80-E100-80000A093738  I600100000000  80000004  ZBP121
# 3  514B0248-1308-1A40-E100-80000A093738  I600100000001   2001465  ZBP310
# 4  514B024B-1308-1A40-E100-80000A093738  I600100000001  10001817  ZBP400
#
#     ValidFrom              ValidTo AddressType  LOAD_ID  \
# 0  0001-01-01  9999-12-31 00:00:00   XXDEFAULT  2663574
# 1  0001-01-01  9999-12-31 00:00:00   XXDEFAULT  2663574
# 2  0001-01-01  9999-12-31 00:00:00   XXDEFAULT  2663574
# 3  0001-01-01  9999-12-31 00:00:00   XXDEFAULT  2663574
# 4  0001-01-01  9999-12-31 00:00:00   XXDEFAULT  2663574
#
#                                  PKG_ID  ASAT_DATE                  INS_DT  \
# 0  C5B08C0B-475A-4383-8288-B471E3F89334 2024-10-31 2024-11-01 17:37:43.967
# ...

# %% [markdown]
# ### dim_bp
# - abc

# %%
df_dim_bp = pd.read_excel("./data/cpn-dwh-data.xlsx", sheet_name="dim_bp")
df_dim_bp.head()
# Out:
#    BPNumber  BPCategory BPType BPGrouping   Title  TitleCode  \
# 0   1000001           2   Z000       Z001  บริษัท        NaN
# 1   1000002           2   Z000       Z001  บริษัท        NaN
# 2   1000003           2   Z000       Z001  บริษัท        NaN
# 3   1000004           2   Z000       Z001  บริษัท        3.0
# 4   1000005           2   Z000       Z001  บริษัท        NaN
#
#                         OrgName1   OrgName2  BPGroupNumber  \
# 0    เซ็นทรัลพัฒนา จำกัด (มหาชน)        NaN      5000243.0
# 1         เซ็นทรัลเทรดดิ้ง จำกัด        NaN      1000446.0
# 2  เซ็นทรัลกาเมนท์แฟคทอรี่ จำกัด        NaN      5000017.0
# 3       สรรพสินค้าเซ็นทรัล จำกัด        NaN      5000018.0
# 4      รากาซเซ เครื่องหนัง จำกัด  **ห้ามใช้      5000124.0
#
#                     BPGroupName1  BPGroupName2 CustomerType  \
# 0                      CPN GROUP           NaN    Corporate
# 1  ซันกลาส ฮัท (ประเทศไทย) จำกัด           NaN    Corporate
# ...
